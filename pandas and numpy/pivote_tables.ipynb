# %%
import pandas as pd

# %%
df = pd.read_excel('sample_pivot.xlsx')

# %%
df
# Out:
#           Date Region                 Type  Units  Sales
# 0   2020-07-11   East  Children's Clothing   18.0    306
# 1   2020-09-23  North  Children's Clothing   14.0    448
# 2   2020-04-02  South     Women's Clothing   17.0    425
# 3   2020-02-28   East  Children's Clothing   26.0    832
# 4   2020-03-19   West     Women's Clothing    3.0     33
# ..         ...    ...                  ...    ...    ...
# 995 2020-02-11   East  Children's Clothing   35.0    735
# 996 2020-12-25  North       Men's Clothing    NaN   1155
# 997 2020-08-31  South       Men's Clothing   13.0    208
# 998 2020-08-23  South     Women's Clothing   17.0    493
# 999 2020-08-17  North     Women's Clothing   25.0    300
#
# [1000 rows x 5 columns]

# %%
pd.pivot_table(df,index = 'Region',values = 'Units')
# Out:
#             Units
# Region
# East    19.732360
# North   19.202643
# South   20.423358
# West    19.294118

# %%
df['Type'].value_counts()
# Out:
# Type
# Women's Clothing       424
# Men's Clothing         291
# Children's Clothing    285
# Name: count, dtype: int64

# %%
get_second_highest = lambda x: pd.DataFrame(x).sort_values(by = 'Sales',ascending=False).iloc[1]

# Apply the lambda function to the 'category' column within each group
result = df.groupby('Type')['Region'].agg(get_second_highest).reset_index()
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#     297                 #  a dictionary lookup on group.name, but group name is not
#     298                 #  pinned in _python_agg_general, only in _aggregate_named
# --> 299                 result = self._aggregate_named(func, *args, **kwargs)
#     300
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, func, *args, **kwargs)
#     325
#     326         obj = self._obj_with_exclusions
# --> 327         result = self._grouper.agg_series(obj, f)
#     328         res = obj._constructor(result, name=obj.name)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/ops.py in ?(self, obj, func, preserve_dtype)
# ...

# %%
df.groupby(['Type','Region']).agg({'Sales':lambda x : pd.DataFrame(x).sort_values('Sales',ascending = False).iloc[1]
                                   })
# Out:
#                             Sales
# Type                Region
# Children's Clothing East     1020
#                     North    1023
#                     South     896
#                     West      990
# Men's Clothing      East      990
#                     North     957
#                     South    1056
#                     West      928
# Women's Clothing    East     1050
#                     North    1089
#                     South     759
#                     West      899
