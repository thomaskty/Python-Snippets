# %%
import pandas as pd

# %%
df = pd.read_excel('sample_pivot.xlsx')

# %%
df
# Out:
#           Date Region                 Type  Units  Sales
# 0   2020-07-11   East  Children's Clothing   18.0    306
# 1   2020-09-23  North  Children's Clothing   14.0    448
# 2   2020-04-02  South     Women's Clothing   17.0    425
# 3   2020-02-28   East  Children's Clothing   26.0    832
# 4   2020-03-19   West     Women's Clothing    3.0     33
# ..         ...    ...                  ...    ...    ...
# 995 2020-02-11   East  Children's Clothing   35.0    735
# 996 2020-12-25  North       Men's Clothing    NaN   1155
# 997 2020-08-31  South       Men's Clothing   13.0    208
# 998 2020-08-23  South     Women's Clothing   17.0    493
# 999 2020-08-17  North     Women's Clothing   25.0    300
#
# [1000 rows x 5 columns]

# %%
pd.pivot_table(df,index = 'Region',values = 'Units')
# Out:
#             Units
# Region
# East    19.732360
# North   19.202643
# South   20.423358
# West    19.294118

# %%
df['Type'].value_counts()
# Out:
# Type
# Women's Clothing       424
# Men's Clothing         291
# Children's Clothing    285
# Name: count, dtype: int64

# %%
get_second_highest = lambda x: pd.DataFrame(x).sort_values(by = 'Sales',ascending=False).iloc[1]

# Apply the lambda function to the 'category' column within each group
result = df.groupby('Type')['Region'].agg(get_second_highest).reset_index()
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#     272                 #  a dictionary lookup on group.name, but group name is not
#     273                 #  pinned in _python_agg_general, only in _aggregate_named
# --> 274                 result = self._aggregate_named(func, *args, **kwargs)
#     275
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py in ?(self, func, *args, **kwargs)
#     286
#     287         obj = self._obj_with_exclusions
# --> 288         result = self.grouper.agg_series(obj, f)
#     289         res = obj._constructor(result, name=obj.name)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py in ?(self, obj, func, preserve_dtype)
#     992             preserve_dtype = True
#     993
# --> 994         result = self._aggregate_series_pure_python(obj, func)
#     995
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py in ?(self, obj, func)
#    1013
#    1014         for i, group in enumerate(splitter):
# -> 1015             res = func(group)
#    1016             res = libreduction.extract_result(res)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py in ?(x)
# --> 285         f = lambda x: func(x, *args, **kwargs)
#
# /var/folders/hd/yplywrn5403_kjkff3dv45qh0000gn/T/ipykernel_1566/4018065584.py in ?(x)
# ----> 1 get_second_highest = lambda x: pd.DataFrame(x).sort_values(by = 'Sales',ascending=False).iloc[1]
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#
# KeyError: 'Sales'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/hd/yplywrn5403_kjkff3dv45qh0000gn/T/ipykernel_1566/4018065584.py in ?()
#       1 get_second_highest = lambda x: pd.DataFrame(x).sort_values(by = 'Sales',ascending=False).iloc[1]
#       2
#       3 # Apply the lambda function to the 'category' column within each group
# ----> 4 result = df.groupby('Type')['Region'].agg(get_second_highest).reset_index()
#       5 result
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#     270             except KeyError:
#     271                 # KeyError raised in test_groupby.test_basic is bc the func does
#     272                 #  a dictionary lookup on group.name, but group name is not
#     273                 #  pinned in _python_agg_general, only in _aggregate_named
# --> 274                 result = self._aggregate_named(func, *args, **kwargs)
#     275
#     276                 # result is a dict whose keys are the elements of result_index
#     277                 result = Series(result, index=self.grouper.result_index)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py in ?(self, func, *args, **kwargs)
#     408
#     409         for name, group in self:
#     410             object.__setattr__(group, "name", name)
#     411
# --> 412             output = func(group, *args, **kwargs)
#     413             output = libreduction.extract_result(output)
#     414             if not initialized:
#     415                 # We only do this validation on the first iteration
#
# /var/folders/hd/yplywrn5403_kjkff3dv45qh0000gn/T/ipykernel_1566/4018065584.py in ?(x)
# ----> 1 get_second_highest = lambda x: pd.DataFrame(x).sort_values(by = 'Sales',ascending=False).iloc[1]
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'Sales'

# %%
df.groupby(['Type','Region']).agg({'Sales':lambda x : pd.DataFrame(x).sort_values('Sales',ascending = False).iloc[0]})
# Out:
#                             Sales
# Type                Region
# Children's Clothing East     1122
#                     North    1088
#                     South     924
#                     West      992
# Men's Clothing      East     1054
#                     North    1155
#                     South    1085
#                     West      930
# Women's Clothing    East     1054
#                     North    1122
#                     South    1122
#                     West     1023
