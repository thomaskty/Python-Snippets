# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[['pclass']]
# Out:
#      pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
# getting the first records
df.head(4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
df.tail(6)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 885         0       3  female  39.0      0      5  29.125        Q   Third
# 886         0       2    male  27.0      0      0  13.000        S  Second
# 887         1       1  female  19.0      0      0  30.000        S   First
# 888         0       3  female   NaN      1      2  23.450        S   Third
# 889         1       1    male  26.0      0      0  30.000        C   First
# 890         0       3    male  32.0      0      0   7.750        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# creating a new csv 
# df1 = df.head()
# df1.to_csv('test.csv')

# %%
# !ls
# Out:
# my_pickle	      numpy_part1.py	    pandas_3.ipynb  pandas_note1.ipynb
# numpy_3.ipynb	      numpy_problems.ipynb  pandas_4.ipynb  test.h5
# Numpy_Notebook.ipynb  pandas2.ipynb	    pandas_5.ipynb

# %%
# if we want to avoid the seperator and how to avoid "column" 
# df = pd.read_csv('path', sep = '#', header = None, names = ['a','b',..],
#   skiprows = [1,2,4,5, na_values = ])

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# storing new data by formating the options
# df_new.to_csv('name_', index = Flase, header = False, sep = "#", columns = [])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# selecting a column 
survived = df['survived']
survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
type(survived)
# Out:
# pandas.core.series.Series

# %%
# multiple columns
df[['survived','sex']]
# Out:
#      survived     sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %%
ht = pd.read_html('https://www.basketball-reference.com/leaders/')

# %%
type(ht)
# Out:
# list

# %%
type(ht[0])
# Out:
# pandas.core.frame.DataFrame

# %%
ht
# Out:
# [                           Totals       Totals.1  Totals.2  Totals.3  \
#  0                           Games  Single Season    Career    Active
#  1                  Minutes Played  Single Season    Career    Active
#  2                     Field Goals  Single Season    Career    Active
#  3             Field Goal Attempts  Single Season    Career    Active
#  4                2-Pt Field Goals  Single Season    Career    Active
#  5        2-Pt Field Goal Attempts  Single Season    Career    Active
#  6                3-Pt Field Goals  Single Season    Career    Active
#  7        3-Pt Field Goal Attempts  Single Season    Career    Active
#  8              Field Goals Missed  Single Season    Career    Active
#  9                     Free Throws  Single Season    Career    Active
#  10            Free Throw Attempts  Single Season    Career    Active
#  11             Offensive Rebounds  Single Season    Career    Active
# ...

# %%
accident = pd.read_csv('https://raw.githubusercontent.com/thomasreji155/Machine-Learning-with-R/master/data_fold/accident.csv')

# %%
accident
# Out:
#           id    weight   dead  airbag seatbelt  frontal sex  ageOFocc  \
# 0          1    25.069  alive    none   belted        1   f        26
# 1          2    25.069  alive  airbag   belted        1   f        72
# 2          3    32.379  alive    none     none        1   f        69
# 3          4   495.444  alive  airbag   belted        1   f        53
# 4          5    25.069  alive    none   belted        1   f        32
# ...      ...       ...    ...     ...      ...      ...  ..       ...
# 14994  14995  1037.204  alive    none   belted        0   m        24
# 14995  14996  1037.204  alive    none   belted        0   f        22
# 14996  14997  1037.204  alive  airbag   belted        1   m        29
# 14997  14998  1037.204  alive  airbag   belted        1   f        28
# 14998  14999  4338.186  alive  airbag   belted        0   f        25
#
#        yearacc     abcat occRole  deploy  injSeverity    caseid
# ...

# %%
s =  """{"name": "thomas","phoneno": 9562348628,"email":"thomasreji155@gmail.com"}"""

# %%
import json

# %%
jdf = json.loads(s)
jdf
# Out:
# {'name': 'thomas', 'phoneno': 9562348628, 'email': 'thomasreji155@gmail.com'}

# %%
pd.DataFrame(jdf,index=[0])
# Out:
#      name     phoneno                    email
# 0  thomas  9562348628  thomasreji155@gmail.com

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()
js
# Out:
# U6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-15T17:25:53Z',
#   'updated_at': '2021-06-16T18:27:47Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42021',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42021',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42021.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42021.patch'},
# ...

# %%
js[0]['title']
# Out:
# 'REF: use only inherit_names in CategoricalIndex'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# REF: use only inherit_names in CategoricalIndex
# BUG: Adding Series to empty DataFrame can reset dtype to float64
# Backport PR #42097 on branch 1.3.x (PERF: lib.generate_slices)
# CLN: use fused type for lib.has_infs
# REGR: Subclassing `Styler` and addressing `from_custom_template`
# [WIP] BUG: fix `Series.argsort`
# REGR: undocumented astype("category").astype(str) type inconsistency between pandas 1.1 & 1.2
# BUG: groupby any/all raising with pd.NA object data
# PERF/CLN: to_csv
# When change default dtype for empty Series?
# CI: disable auto-cancel for master branch
# BUG: error writing sparse DataFrame to HDF
# BUG: pd.to_datetime(infer_datetime_format=True) drops timezone
# DOC: How to use storage_option param here to integrate with GCP bucket?
# BUG: rolling std can't handle mixture of (relatively) big and small numbers
# BUG: avoid unnecessary casting in CategoricalIndex.reindex
# Allow passing custom sentinel into MultiIndex.format
# ...

# %%
pd.DataFrame(js, columns = ['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
# ...

# %%
userdata = []
for i in range(len(js)):
    userdata.append(js[i]['user'])

pd.DataFrame(userdata)
# Out:
# 242565...
# 21  https://avatars.githubusercontent.com/u/919008...
# 22  https://avatars.githubusercontent.com/u/700393...
# 23  https://avatars.githubusercontent.com/u/370118...
# 24  https://avatars.githubusercontent.com/u/370118...
# 25  https://avatars.githubusercontent.com/u/807896...
# 26  https://avatars.githubusercontent.com/u/408852...
# 27  https://avatars.githubusercontent.com/u/201644...
# 28  https://avatars.githubusercontent.com/u/242565...
# 29  https://avatars.githubusercontent.com/u/829095...
#
#                                              url  \
# 0      https://api.github.com/users/jbrockmendel
# 1        https://api.github.com/users/JBGreisman
# 2   https://api.github.com/users/meeseeksmachine
# 3        https://api.github.com/users/mzeitlin11
# 4          https://api.github.com/users/attack68
# 5          https://api.github.com/users/attack68
# 6   https://api.github.com/users/simonjayhawkins
# 7        https://api.github.com/users/mzeitlin11
# ...

# %%
json_data = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues') 
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#              login        id               node_id  \
# 0     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1       JBGreisman   6944142  MDQ6VXNlcjY5NDQxNDI=
# 2  meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 3       mzeitlin11  37011898  MDQ6VXNlcjM3MDExODk4
# 4         attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/807896...
# 1  https://avatars.githubusercontent.com/u/694414...
# 2  https://avatars.githubusercontent.com/u/395042...
# 3  https://avatars.githubusercontent.com/u/370118...
# 4  https://avatars.githubusercontent.com/u/242565...
#
#                                             url  \
# 0     https://api.github.com/users/jbrockmendel
# 1       https://api.github.com/users/JBGreisman
# 2  https://api.github.com/users/meeseeksmachine
# 3       https://api.github.com/users/mzeitlin11
# 4         https://api.github.com/users/attack68
#
# ...

# %%
print('hello')
# Out:
# hello
